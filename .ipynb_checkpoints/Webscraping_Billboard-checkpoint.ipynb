# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
# Output: df with 100 rows and 2 columns: name of artist and name of song

# %%
url = "https://www.billboard.com/charts/hot-100/"

# %%
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
songs = [song.get_text() for song in soup.select("h3.c-title")]

# %%
songs
# Out:
# ['\n\n\t\n\t\t\n\t\t\t\t\tManchild\t\t\n\t\t\t\t\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\t\n\t\t\t\t\tSabrina Carpenter, SZA, Ariana Grande Win Multiple Awards at 2025 Kids’ Choice Awards (Full Winners List)\t\t\n\t\t\t\t\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tGains in Weekly Performance\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tAdditional Awards\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tManchild\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tOrdinary\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tWhat I Want\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tJust In Case\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tLuther\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  "\n\n\t\n\t\n\t\t\n\t\t\t\t\tI'm The Problem\t\t\n\t\n",
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tA Bar Song (Tipsy)\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tDie With A Smile\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tLose Control\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tBeautiful Things\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tPink Pony Club\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tNokia\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tAnxiety\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tMutt\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tI Had Some Help\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tBirds Of A Feather\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tEspresso\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tBlue Strips\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tAll The Way\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tWorst Way\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tI Got Better\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tLove Somebody\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tLove Me Not\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tAPT.\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  "\n\n\t\n\t\n\t\t\n\t\t\t\t\tI Ain't Coming Back\t\t\n\t\n",
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\t30 For 30\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSports Car\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  "\n\n\t\n\t\n\t\t\n\t\t\t\t\tWeren't For The Wind\t\t\n\t\n",
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\t20 Cigarettes\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tMystical Magical\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  "\n\n\t\n\t\n\t\t\n\t\t\t\t\tSorry I'm Here For Someone Else\t\t\n\t\n",
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tBack To Friends\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tTimeless\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tUndressed\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  "\n\n\t\n\t\n\t\t\n\t\t\t\t\tThat's So True\t\t\n\t\n",
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tHip-Hop\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tMessy\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSuperman\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tGood News\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tBurning Blue\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tAbracadabra\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tTypa\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tTV Off\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tWildflower\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tAm I Okay?\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tCry For Me\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tNo One Noticed\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tBackup Plan\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tHappen To Me\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSquabble Up\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tJust Keep Watching\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tTN\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tBloodline\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSharks\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tShake It To The Max (Fly)\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tTouch Me Like A Gangster\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSomebody Loves Me\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tAfter All The Bars Are Closed\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tAzizam\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tDark Til Daylight\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tBanned From NO\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tWelcome To Tha Carter\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tDark Thoughts\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tParty 4 U\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tBells\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tWhim Whamiee\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tIndigo\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  "\n\n\t\n\t\n\t\t\n\t\t\t\t\tYour Way's Better\t\t\n\t\n",
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tOWA OWA\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  "\n\n\t\n\t\n\t\t\n\t\t\t\t\tI'm A Little Crazy\t\t\n\t\n",
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tEyes Are Closed\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tPeekaboo\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tFame Is A Gun\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSapphire\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tHard Fought Hallelujah\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tBackseat Driver\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tMarlboro Rojo\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tHouse Again\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  "\n\n\t\n\t\n\t\t\n\t\t\t\t\tWhere'd That Girl Go\t\t\n\t\n",
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tRather Lie\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tAmen\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tThought It Was Love\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tTu Sancho\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tKick Myself\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSkoal, Chevy, And Browning\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tMe Jalo\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tFalling Apart\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  "\n\n\t\n\t\n\t\t\n\t\t\t\t\tFix What You Didn't Break\t\t\n\t\n",
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tIf You Were Mine\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tGnarly\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tKiss Her In Front Of You\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tEOO\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tCotton Candy\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tCliche\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tType Dangerous\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tMissing\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tKing Carter\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tBusy Woman\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tNice To Meet You\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tPor Esos Ojos\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSongwriter(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tProducer(s):\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tImprint/Promotion Label:\t\t\n\t\n',
#  "\n\n\t\n\t\n\t\t\n\t\t\t\t\tJon Bernthal Joins Tom Holland in 'Spider-Man: Brand New Day'\xa0\t\t\n\t\n",
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tSophie Cunningham’s $1M Social Jump Dwarfs WNBA Fines\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tEmily Blunt’s Latest Comments About John Krasinski Show the Truth Behind Those Divorce Rumors\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tDonald Trump Makes History As First President In 116 Years Not Invited To Attend NAACP Convention\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tWhy Barbra Streisand Was “a Bit” Scared to Hit Studio With Bob Dylan to Record New Duet\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tCardi B Unveils Cover Art And Release Date For Highly Anticipated Sophomore Album\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tTribes Dispute Kalshi Claims of ‘Productive’ Talks on Futures\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tZohran Mamdani, Brad Lander Promote ‘Politics of the Future’ on ‘Colbert’\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tFollow Us\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tHave a Tip?\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tThe Daily\t\t\n\t\n',
#  '\n\n\t\n\t\n\t\t\n\t\t\t\t\tHave a Tip?\t\t\n\t\n']

# %%
cleaned_songs = [songs.strip() for songs in songs]

# %%
cleaned_songs
# Out:
# ['Manchild',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Sabrina Carpenter, SZA, Ariana Grande Win Multiple Awards at 2025 Kids’ Choice Awards (Full Winners List)',
#  'Gains in Weekly Performance',
#  'Additional Awards',
#  'Manchild',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Ordinary',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'What I Want',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Just In Case',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Luther',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  "I'm The Problem",
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'A Bar Song (Tipsy)',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Die With A Smile',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Lose Control',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Beautiful Things',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Pink Pony Club',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Nokia',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Anxiety',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Mutt',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'I Had Some Help',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Birds Of A Feather',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Espresso',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Blue Strips',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'All The Way',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Worst Way',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'I Got Better',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Love Somebody',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Love Me Not',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'APT.',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  "I Ain't Coming Back",
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  '30 For 30',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Sports Car',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  "Weren't For The Wind",
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  '20 Cigarettes',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Mystical Magical',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  "Sorry I'm Here For Someone Else",
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Back To Friends',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Timeless',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Undressed',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  "That's So True",
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Hip-Hop',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Messy',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Superman',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Good News',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Burning Blue',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Abracadabra',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Typa',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'TV Off',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Wildflower',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Am I Okay?',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Cry For Me',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'No One Noticed',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Backup Plan',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Happen To Me',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Squabble Up',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Just Keep Watching',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'TN',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Bloodline',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Sharks',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Shake It To The Max (Fly)',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Touch Me Like A Gangster',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Somebody Loves Me',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'After All The Bars Are Closed',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Azizam',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Dark Til Daylight',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Banned From NO',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Welcome To Tha Carter',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Dark Thoughts',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Party 4 U',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Bells',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Whim Whamiee',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Indigo',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  "Your Way's Better",
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'OWA OWA',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  "I'm A Little Crazy",
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Eyes Are Closed',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Peekaboo',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Fame Is A Gun',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Sapphire',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Hard Fought Hallelujah',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Backseat Driver',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Marlboro Rojo',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'House Again',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  "Where'd That Girl Go",
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Rather Lie',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Amen',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Thought It Was Love',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Tu Sancho',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Kick Myself',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Skoal, Chevy, And Browning',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Me Jalo',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Falling Apart',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  "Fix What You Didn't Break",
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'If You Were Mine',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Gnarly',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Kiss Her In Front Of You',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'EOO',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Cotton Candy',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Cliche',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Type Dangerous',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Missing',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'King Carter',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Busy Woman',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Nice To Meet You',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  'Por Esos Ojos',
#  'Songwriter(s):',
#  'Producer(s):',
#  'Imprint/Promotion Label:',
#  "Jon Bernthal Joins Tom Holland in 'Spider-Man: Brand New Day'",
#  'Sophie Cunningham’s $1M Social Jump Dwarfs WNBA Fines',
#  'Emily Blunt’s Latest Comments About John Krasinski Show the Truth Behind Those Divorce Rumors',
#  'Donald Trump Makes History As First President In 116 Years Not Invited To Attend NAACP Convention',
#  'Why Barbra Streisand Was “a Bit” Scared to Hit Studio With Bob Dylan to Record New Duet',
#  'Cardi B Unveils Cover Art And Release Date For Highly Anticipated Sophomore Album',
#  'Tribes Dispute Kalshi Claims of ‘Productive’ Talks on Futures',
#  'Zohran Mamdani, Brad Lander Promote ‘Politics of the Future’ on ‘Colbert’',
#  'Follow Us',
#  'Have a Tip?',
#  'The Daily',
#  'Have a Tip?']

# %%
# Filtering only song names
filtered_songs = [songs for songs in cleaned_songs if songs not in ["Songwriter(s):", "Producer(s):", "Imprint/Promotion Label:", 'Sabrina Carpenter Says She’s Considered Banning Phones at Her Concerts', "Gains in Weekly Performance", 'Additional Awards', '\'Star Wars\' "Looks Terrible" in Screening of Long Lost Original 1977 Version', 'Wayne Gretzky’s Daughter Paulina’s Yellow Bikini Photoshoot Shows She’s in Her ‘Unbothered’ Era', 'MLB’s Rays in Advanced Talks for $1.7B Sale to Florida Home Builder', "Man Sits On and Breaks Crystal-Encrusted 'Van Gogh' Chair in Italian Museum Before Fleeing",  '‘Dragon’s Lair’: James Bobin in Talks to Direct Video Game Adaptation for Ryan Reynolds, Netflix', 'Ye Says He Plans To Drop 10 Songs From ‘Bully’ This Week: “Still Working On The\xa0Album”', 'Just How Big Is the Sports\xa0Industry?', 'Bruce Springsteen: ‘Time Is Finite, and Your Performing Time Is Finite’','Follow Us', "Have a Tip?", 'The Daily']]

# %%
filtered_songs
# Out:
# ['Manchild',
#  'Sabrina Carpenter, SZA, Ariana Grande Win Multiple Awards at 2025 Kids’ Choice Awards (Full Winners List)',
#  'Manchild',
#  'Ordinary',
#  'What I Want',
#  'Just In Case',
#  'Luther',
#  "I'm The Problem",
#  'A Bar Song (Tipsy)',
#  'Die With A Smile',
#  'Lose Control',
#  'Beautiful Things',
#  'Pink Pony Club',
#  'Nokia',
#  'Anxiety',
#  'Mutt',
#  'I Had Some Help',
#  'Birds Of A Feather',
#  'Espresso',
#  'Blue Strips',
#  'All The Way',
#  'Worst Way',
#  'I Got Better',
#  'Love Somebody',
#  'Love Me Not',
#  'APT.',
#  "I Ain't Coming Back",
#  '30 For 30',
#  'Sports Car',
#  "Weren't For The Wind",
#  '20 Cigarettes',
#  'Mystical Magical',
#  "Sorry I'm Here For Someone Else",
#  'Back To Friends',
#  'Timeless',
#  'Undressed',
#  "That's So True",
#  'Hip-Hop',
#  'Messy',
#  'Superman',
#  'Good News',
#  'Burning Blue',
#  'Abracadabra',
#  'Typa',
#  'TV Off',
#  'Wildflower',
#  'Am I Okay?',
#  'Cry For Me',
#  'No One Noticed',
#  'Backup Plan',
#  'Happen To Me',
#  'Squabble Up',
#  'Just Keep Watching',
#  'TN',
#  'Bloodline',
#  'Sharks',
#  'Shake It To The Max (Fly)',
#  'Touch Me Like A Gangster',
#  'Somebody Loves Me',
#  'After All The Bars Are Closed',
#  'Azizam',
#  'Dark Til Daylight',
#  'Banned From NO',
#  'Welcome To Tha Carter',
#  'Dark Thoughts',
#  'Party 4 U',
#  'Bells',
#  'Whim Whamiee',
#  'Indigo',
#  "Your Way's Better",
#  'OWA OWA',
#  "I'm A Little Crazy",
#  'Eyes Are Closed',
#  'Peekaboo',
#  'Fame Is A Gun',
#  'Sapphire',
#  'Hard Fought Hallelujah',
#  'Backseat Driver',
#  'Marlboro Rojo',
#  'House Again',
#  "Where'd That Girl Go",
#  'Rather Lie',
#  'Amen',
#  'Thought It Was Love',
#  'Tu Sancho',
#  'Kick Myself',
#  'Skoal, Chevy, And Browning',
#  'Me Jalo',
#  'Falling Apart',
#  "Fix What You Didn't Break",
#  'If You Were Mine',
#  'Gnarly',
#  'Kiss Her In Front Of You',
#  'EOO',
#  'Cotton Candy',
#  'Cliche',
#  'Type Dangerous',
#  'Missing',
#  'King Carter',
#  'Busy Woman',
#  'Nice To Meet You',
#  'Por Esos Ojos',
#  "Jon Bernthal Joins Tom Holland in 'Spider-Man: Brand New Day'",
#  'Sophie Cunningham’s $1M Social Jump Dwarfs WNBA Fines',
#  'Emily Blunt’s Latest Comments About John Krasinski Show the Truth Behind Those Divorce Rumors',
#  'Donald Trump Makes History As First President In 116 Years Not Invited To Attend NAACP Convention',
#  'Why Barbra Streisand Was “a Bit” Scared to Hit Studio With Bob Dylan to Record New Duet',
#  'Cardi B Unveils Cover Art And Release Date For Highly Anticipated Sophomore Album',
#  'Tribes Dispute Kalshi Claims of ‘Productive’ Talks on Futures',
#  'Zohran Mamdani, Brad Lander Promote ‘Politics of the Future’ on ‘Colbert’']

# %%
len(filtered_songs)
# Out:
# 110

# %%
unique_songs = list(set(filtered_songs))

# %%
len(unique_songs)
# Out:
# 109

# %%
artists = [artist.get_text() for artist in soup.select("span.c-label")]

# %%
artists
# Out:
# ['\n\t\n\t1\n',
#  '\n\t\n\tNEW\n',
#  '\n\t\n\tNEW\n',
#  '\n\t\n\tSabrina Carpenter\n',
#  '\n\t\n\t-\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t-\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t2\n',
#  '\n\t\n\tAlex Warren\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t18\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t18\n',
#  '\n\t\n\t3\n',
#  '\n\t\n\tMorgan Wallen Featuring Tate McRae\n',
#  '\n\t\n\t2\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t4\n',
#  '\n\t\n\t2\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t4\n',
#  '\n\t\n\t4\n',
#  '\n\t\n\tMorgan Wallen\n',
#  '\n\t\n\t3\n',
#  '\n\t\n\t2\n',
#  '\n\t\n\t12\n',
#  '\n\t\n\t3\n',
#  '\n\t\n\t2\n',
#  '\n\t\n\t12\n',
#  '\n\t\n\t5\n',
#  '\n\t\n\tKendrick Lamar & SZA\n',
#  '\n\t\n\t4\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t29\n',
#  '\n\t\n\t4\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t29\n',
#  '\n\t\n\t6\n',
#  '\n\t\n\tMorgan Wallen\n',
#  '\n\t\n\t5\n',
#  '\n\t\n\t2\n',
#  '\n\t\n\t19\n',
#  '\n\t\n\t5\n',
#  '\n\t\n\t2\n',
#  '\n\t\n\t19\n',
#  '\n\t\n\t7\n',
#  '\n\t\n\tShaboozey\n',
#  '\n\t\n\t6\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t61\n',
#  '\n\t\n\t6\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t61\n',
#  '\n\t\n\t8\n',
#  '\n\t\n\tLady Gaga & Bruno Mars\n',
#  '\n\t\n\t7\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t43\n',
#  '\n\t\n\t7\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t43\n',
#  '\n\t\n\t9\n',
#  '\n\t\n\tTeddy Swims\n',
#  '\n\t\n\t8\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t95\n',
#  '\n\t\n\t8\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t95\n',
#  '\n\t\n\t10\n',
#  '\n\t\n\tBenson Boone\n',
#  '\n\t\n\t9\n',
#  '\n\t\n\t2\n',
#  '\n\t\n\t72\n',
#  '\n\t\n\t9\n',
#  '\n\t\n\t2\n',
#  '\n\t\n\t72\n',
#  '\n\t\n\t11\n',
#  '\n\t\n\tChappell Roan\n',
#  '\n\t\n\t12\n',
#  '\n\t\n\t4\n',
#  '\n\t\n\t52\n',
#  '\n\t\n\t12\n',
#  '\n\t\n\t4\n',
#  '\n\t\n\t52\n',
#  '\n\t\n\t12\n',
#  '\n\t\n\tDrake\n',
#  '\n\t\n\t10\n',
#  '\n\t\n\t2\n',
#  '\n\t\n\t17\n',
#  '\n\t\n\t10\n',
#  '\n\t\n\t2\n',
#  '\n\t\n\t17\n',
#  '\n\t\n\t13\n',
#  '\n\t\n\tDoechii\n',
#  '\n\t\n\t11\n',
#  '\n\t\n\t9\n',
#  '\n\t\n\t14\n',
#  '\n\t\n\t11\n',
#  '\n\t\n\t9\n',
#  '\n\t\n\t14\n',
#  '\n\t\n\t14\n',
#  '\n\t\n\tLeon Thomas\n',
#  '\n\t\n\t14\n',
#  '\n\t\n\t13\n',
#  '\n\t\n\t19\n',
#  '\n\t\n\t14\n',
#  '\n\t\n\t13\n',
#  '\n\t\n\t19\n',
#  '\n\t\n\t15\n',
#  '\n\t\n\tPost Malone Featuring Morgan Wallen\n',
#  '\n\t\n\t15\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t57\n',
#  '\n\t\n\t15\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t57\n',
#  '\n\t\n\t16\n',
#  '\n\t\n\tBillie Eilish\n',
#  '\n\t\n\t13\n',
#  '\n\t\n\t2\n',
#  '\n\t\n\t56\n',
#  '\n\t\n\t13\n',
#  '\n\t\n\t2\n',
#  '\n\t\n\t56\n',
#  '\n\t\n\t17\n',
#  '\n\t\n\tSabrina Carpenter\n',
#  '\n\t\n\t20\n',
#  '\n\t\n\t3\n',
#  '\n\t\n\t61\n',
#  '\n\t\n\t20\n',
#  '\n\t\n\t3\n',
#  '\n\t\n\t61\n',
#  '\n\t\n\t18\n',
#  '\n\t\n\tJessie Murph\n',
#  '\n\t\n\t16\n',
#  '\n\t\n\t15\n',
#  '\n\t\n\t9\n',
#  '\n\t\n\t16\n',
#  '\n\t\n\t15\n',
#  '\n\t\n\t9\n',
#  '\n\t\n\t19\n',
#  '\n\t\n\tBigXthaPlug Featuring Bailey Zimmerman\n',
#  '\n\t\n\t18\n',
#  '\n\t\n\t4\n',
#  '\n\t\n\t10\n',
#  '\n\t\n\t18\n',
#  '\n\t\n\t4\n',
#  '\n\t\n\t10\n',
#  '\n\t\n\t20\n',
#  '\n\t\n\tRiley Green\n',
#  '\n\t\n\t23\n',
#  '\n\t\n\t20\n',
#  '\n\t\n\t22\n',
#  '\n\t\n\t23\n',
#  '\n\t\n\t20\n',
#  '\n\t\n\t22\n',
#  '\n\t\n\t21\n',
#  '\n\t\n\tMorgan Wallen\n',
#  '\n\t\n\t17\n',
#  '\n\t\n\t7\n',
#  '\n\t\n\t4\n',
#  '\n\t\n\t17\n',
#  '\n\t\n\t7\n',
#  '\n\t\n\t4\n',
#  '\n\t\n\t22\n',
#  '\n\t\n\tMorgan Wallen\n',
#  '\n\t\n\t19\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t34\n',
#  '\n\t\n\t19\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t34\n',
#  '\n\t\n\t23\n',
#  '\n\t\n\tRavyn Lenae\n',
#  '\n\t\n\t36\n',
#  '\n\t\n\t23\n',
#  '\n\t\n\t11\n',
#  '\n\t\n\t36\n',
#  '\n\t\n\t23\n',
#  '\n\t\n\t11\n',
#  '\n\t\n\t24\n',
#  '\n\t\n\tROSE & Bruno Mars\n',
#  '\n\t\n\t24\n',
#  '\n\t\n\t3\n',
#  '\n\t\n\t34\n',
#  '\n\t\n\t24\n',
#  '\n\t\n\t3\n',
#  '\n\t\n\t34\n',
#  '\n\t\n\t25\n',
#  '\n\t\n\tMorgan Wallen Featuring Post Malone\n',
#  '\n\t\n\t21\n',
#  '\n\t\n\t8\n',
#  '\n\t\n\t8\n',
#  '\n\t\n\t21\n',
#  '\n\t\n\t8\n',
#  '\n\t\n\t8\n',
#  '\n\t\n\t26\n',
#  '\n\t\n\tSZA With Kendrick Lamar\n',
#  '\n\t\n\t28\n',
#  '\n\t\n\t10\n',
#  '\n\t\n\t25\n',
#  '\n\t\n\t28\n',
#  '\n\t\n\t10\n',
#  '\n\t\n\t25\n',
#  '\n\t\n\t27\n',
#  '\n\t\n\tTate McRae\n',
#  '\n\t\n\t22\n',
#  '\n\t\n\t16\n',
#  '\n\t\n\t20\n',
#  '\n\t\n\t22\n',
#  '\n\t\n\t16\n',
#  '\n\t\n\t20\n',
#  '\n\t\n\t28\n',
#  '\n\t\n\tElla Langley\n',
#  '\n\t\n\t30\n',
#  '\n\t\n\t28\n',
#  '\n\t\n\t19\n',
#  '\n\t\n\t30\n',
#  '\n\t\n\t28\n',
#  '\n\t\n\t19\n',
#  '\n\t\n\t29\n',
#  '\n\t\n\tMorgan Wallen\n',
#  '\n\t\n\t27\n',
#  '\n\t\n\t20\n',
#  '\n\t\n\t4\n',
#  '\n\t\n\t27\n',
#  '\n\t\n\t20\n',
#  '\n\t\n\t4\n',
#  '\n\t\n\t30\n',
#  '\n\t\n\tBenson Boone\n',
#  '\n\t\n\t35\n',
#  '\n\t\n\t30\n',
#  '\n\t\n\t7\n',
#  '\n\t\n\t35\n',
#  '\n\t\n\t30\n',
#  '\n\t\n\t7\n',
#  '\n\t\n\t31\n',
#  '\n\t\n\tBenson Boone\n',
#  '\n\t\n\t32\n',
#  '\n\t\n\t30\n',
#  '\n\t\n\t15\n',
#  '\n\t\n\t32\n',
#  '\n\t\n\t30\n',
#  '\n\t\n\t15\n',
#  '\n\t\n\t32\n',
#  '\n\t\n\tsombr\n',
#  '\n\t\n\t38\n',
#  '\n\t\n\t32\n',
#  '\n\t\n\t11\n',
#  '\n\t\n\t38\n',
#  '\n\t\n\t32\n',
#  '\n\t\n\t11\n',
#  '\n\t\n\t33\n',
#  '\n\t\n\tThe Weeknd & Playboi Carti\n',
#  '\n\t\n\t31\n',
#  '\n\t\n\t3\n',
#  '\n\t\n\t37\n',
#  '\n\t\n\t31\n',
#  '\n\t\n\t3\n',
#  '\n\t\n\t37\n',
#  '\n\t\n\t34\n',
#  '\n\t\n\tsombr\n',
#  '\n\t\n\t25\n',
#  '\n\t\n\t25\n',
#  '\n\t\n\t10\n',
#  '\n\t\n\t25\n',
#  '\n\t\n\t25\n',
#  '\n\t\n\t10\n',
#  '\n\t\n\t35\n',
#  '\n\t\n\tGracie Abrams\n',
#  '\n\t\n\t37\n',
#  '\n\t\n\t6\n',
#  '\n\t\n\t34\n',
#  '\n\t\n\t37\n',
#  '\n\t\n\t6\n',
#  '\n\t\n\t34\n',
#  '\n\t\n\t36\n',
#  '\n\t\n\tNEW\n',
#  '\n\t\n\tNEW\n',
#  '\n\t\n\tLil Wayne & BigXthaPlug Featuring Jay Jones\n',
#  '\n\t\n\t-\n',
#  '\n\t\n\t36\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t-\n',
#  '\n\t\n\t36\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t37\n',
#  '\n\t\n\tLola Young\n',
#  '\n\t\n\t29\n',
#  '\n\t\n\t14\n',
#  '\n\t\n\t28\n',
#  '\n\t\n\t29\n',
#  '\n\t\n\t14\n',
#  '\n\t\n\t28\n',
#  '\n\t\n\t38\n',
#  '\n\t\n\tMorgan Wallen\n',
#  '\n\t\n\t26\n',
#  '\n\t\n\t8\n',
#  '\n\t\n\t5\n',
#  '\n\t\n\t26\n',
#  '\n\t\n\t8\n',
#  '\n\t\n\t5\n',
#  '\n\t\n\t39\n',
#  '\n\t\n\tShaboozey\n',
#  '\n\t\n\t44\n',
#  '\n\t\n\t34\n',
#  '\n\t\n\t29\n',
#  '\n\t\n\t44\n',
#  '\n\t\n\t34\n',
#  '\n\t\n\t29\n',
#  '\n\t\n\t40\n',
#  '\n\t\n\tMariah The Scientist\n',
#  '\n\t\n\t41\n',
#  '\n\t\n\t25\n',
#  '\n\t\n\t6\n',
#  '\n\t\n\t41\n',
#  '\n\t\n\t25\n',
#  '\n\t\n\t6\n',
#  '\n\t\n\t41\n',
#  '\n\t\n\tLady Gaga\n',
#  '\n\t\n\t42\n',
#  '\n\t\n\t13\n',
#  '\n\t\n\t19\n',
#  '\n\t\n\t42\n',
#  '\n\t\n\t13\n',
#  '\n\t\n\t19\n',
#  '\n\t\n\t42\n',
#  '\n\t\n\tNEW\n',
#  '\n\t\n\tNEW\n',
#  '\n\t\n\tGloRilla\n',
#  '\n\t\n\t-\n',
#  '\n\t\n\t42\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t-\n',
#  '\n\t\n\t42\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t43\n',
#  '\n\t\n\tKendrick Lamar Featuring Lefty Gunplay\n',
#  '\n\t\n\t40\n',
#  '\n\t\n\t2\n',
#  '\n\t\n\t29\n',
#  '\n\t\n\t40\n',
#  '\n\t\n\t2\n',
#  '\n\t\n\t29\n',
#  '\n\t\n\t44\n',
#  '\n\t\n\tBillie Eilish\n',
#  '\n\t\n\t48\n',
#  '\n\t\n\t17\n',
#  '\n\t\n\t52\n',
#  '\n\t\n\t48\n',
#  '\n\t\n\t17\n',
#  '\n\t\n\t52\n',
#  '\n\t\n\t45\n',
#  '\n\t\n\tMegan Moroney\n',
#  '\n\t\n\t34\n',
#  '\n\t\n\t34\n',
#  '\n\t\n\t40\n',
#  '\n\t\n\t34\n',
#  '\n\t\n\t34\n',
#  '\n\t\n\t40\n',
#  '\n\t\n\t46\n',
#  '\n\t\n\tThe Weeknd\n',
#  '\n\t\n\t46\n',
#  '\n\t\n\t12\n',
#  '\n\t\n\t19\n',
#  '\n\t\n\t46\n',
#  '\n\t\n\t12\n',
#  '\n\t\n\t19\n',
#  '\n\t\n\t47\n',
#  '\n\t\n\tThe Marias\n',
#  '\n\t\n\t39\n',
#  '\n\t\n\t22\n',
#  '\n\t\n\t37\n',
#  '\n\t\n\t39\n',
#  '\n\t\n\t22\n',
#  '\n\t\n\t37\n',
#  '\n\t\n\t48\n',
#  '\n\t\n\tBailey Zimmerman & Luke Combs\n',
#  '\n\t\n\t52\n',
#  '\n\t\n\t36\n',
#  '\n\t\n\t6\n',
#  '\n\t\n\t52\n',
#  '\n\t\n\t36\n',
#  '\n\t\n\t6\n',
#  '\n\t\n\t49\n',
#  '\n\t\n\tRussell Dickerson\n',
#  '\n\t\n\t54\n',
#  '\n\t\n\t49\n',
#  '\n\t\n\t8\n',
#  '\n\t\n\t54\n',
#  '\n\t\n\t49\n',
#  '\n\t\n\t8\n',
#  '\n\t\n\t50\n',
#  '\n\t\n\tKendrick Lamar\n',
#  '\n\t\n\t47\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t29\n',
#  '\n\t\n\t47\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t29\n',
#  '\n\t\n\t51\n',
#  '\n\t\n\tTate McRae\n',
#  '\n\t\n\t33\n',
#  '\n\t\n\t33\n',
#  '\n\t\n\t2\n',
#  '\n\t\n\t33\n',
#  '\n\t\n\t33\n',
#  '\n\t\n\t2\n',
#  '\n\t\n\t52\n',
#  '\n\t\n\tMorgan Wallen\n',
#  '\n\t\n\t43\n',
#  '\n\t\n\t31\n',
#  '\n\t\n\t4\n',
#  '\n\t\n\t43\n',
#  '\n\t\n\t31\n',
#  '\n\t\n\t4\n',
#  '\n\t\n\t53\n',
#  '\n\t\n\tAlex Warren With Jelly Roll\n',
#  '\n\t\n\t45\n',
#  '\n\t\n\t32\n',
#  '\n\t\n\t3\n',
#  '\n\t\n\t45\n',
#  '\n\t\n\t32\n',
#  '\n\t\n\t3\n',
#  '\n\t\n\t54\n',
#  '\n\t\n\tNEW\n',
#  '\n\t\n\tNEW\n',
#  '\n\t\n\tLil Wayne, Jelly Roll & Big Sean\n',
#  '\n\t\n\t-\n',
#  '\n\t\n\t54\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t-\n',
#  '\n\t\n\t54\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t55\n',
#  '\n\t\n\tMOLIY, Silent Addy, Skillibeng & Shenseea\n',
#  '\n\t\n\t56\n',
#  '\n\t\n\t55\n',
#  '\n\t\n\t4\n',
#  '\n\t\n\t56\n',
#  '\n\t\n\t55\n',
#  '\n\t\n\t4\n',
#  '\n\t\n\t56\n',
#  '\n\t\n\tNEW\n',
#  '\n\t\n\tNEW\n',
#  '\n\t\n\tJessie Murph\n',
#  '\n\t\n\t-\n',
#  '\n\t\n\t56\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t-\n',
#  '\n\t\n\t56\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t57\n',
#  '\n\t\n\tPARTYNEXTDOOR & Drake\n',
#  '\n\t\n\t59\n',
#  '\n\t\n\t30\n',
#  '\n\t\n\t17\n',
#  '\n\t\n\t59\n',
#  '\n\t\n\t30\n',
#  '\n\t\n\t17\n',
#  '\n\t\n\t58\n',
#  '\n\t\n\tThomas Rhett\n',
#  '\n\t\n\t60\n',
#  '\n\t\n\t58\n',
#  '\n\t\n\t7\n',
#  '\n\t\n\t60\n',
#  '\n\t\n\t58\n',
#  '\n\t\n\t7\n',
#  '\n\t\n\t59\n',
#  '\n\t\n\tEd Sheeran\n',
#  '\n\t\n\t61\n',
#  '\n\t\n\t28\n',
#  '\n\t\n\t10\n',
#  '\n\t\n\t61\n',
#  '\n\t\n\t28\n',
#  '\n\t\n\t10\n',
#  '\n\t\n\t60\n',
#  '\n\t\n\tMorgan Wallen\n',
#  '\n\t\n\t49\n',
#  '\n\t\n\t49\n',
#  '\n\t\n\t4\n',
#  '\n\t\n\t49\n',
#  '\n\t\n\t49\n',
#  '\n\t\n\t4\n',
#  '\n\t\n\t61\n',
#  '\n\t\n\tNEW\n',
#  '\n\t\n\tNEW\n',
#  '\n\t\n\tLil Wayne\n',
#  '\n\t\n\t-\n',
#  '\n\t\n\t61\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t-\n',
#  '\n\t\n\t61\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t62\n',
#  '\n\t\n\tNEW\n',
#  '\n\t\n\tNEW\n',
#  '\n\t\n\tLil Wayne\n',
#  '\n\t\n\t-\n',
#  '\n\t\n\t62\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t-\n',
#  '\n\t\n\t62\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t63\n',
#  '\n\t\n\tLil Tecca\n',
#  '\n\t\n\t53\n',
#  '\n\t\n\t28\n',
#  '\n\t\n\t13\n',
#  '\n\t\n\t53\n',
#  '\n\t\n\t28\n',
#  '\n\t\n\t13\n',
#  '\n\t\n\t64\n',
#  '\n\t\n\tCharli xcx\n',
#  '\n\t\n\t62\n',
#  '\n\t\n\t55\n',
#  '\n\t\n\t8\n',
#  '\n\t\n\t62\n',
#  '\n\t\n\t55\n',
#  '\n\t\n\t8\n',
#  '\n\t\n\t65\n',
#  '\n\t\n\tNEW\n',
#  '\n\t\n\tNEW\n',
#  '\n\t\n\tLil Wayne\n',
#  '\n\t\n\t-\n',
#  '\n\t\n\t65\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t-\n',
#  '\n\t\n\t65\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t66\n',
#  '\n\t\n\tPLUTO & YKNIECE\n',
#  '\n\t\n\t51\n',
#  '\n\t\n\t51\n',
#  '\n\t\n\t8\n',
#  '\n\t\n\t51\n',
#  '\n\t\n\t51\n',
#  '\n\t\n\t8\n',
#  '\n\t\n\t67\n',
#  '\n\t\n\tSam Barber Featuring Avery Anna\n',
#  '\n\t\n\t65\n',
#  '\n\t\n\t40\n',
#  '\n\t\n\t27\n',
#  '\n\t\n\t65\n',
#  '\n\t\n\t40\n',
#  '\n\t\n\t27\n',
#  '\n\t\n\t68\n',
#  '\n\t\n\tForrest Frank\n',
#  '\n\t\n\t63\n',
#  '\n\t\n\t61\n',
#  '\n\t\n\t8\n',
#  '\n\t\n\t63\n',
#  '\n\t\n\t61\n',
#  '\n\t\n\t8\n',
#  '\n\t\n\t69\n',
#  '\n\t\n\tLil Tecca\n',
#  '\n\t\n\t50\n',
#  '\n\t\n\t50\n',
#  '\n\t\n\t2\n',
#  '\n\t\n\t50\n',
#  '\n\t\n\t50\n',
#  '\n\t\n\t2\n',
#  '\n\t\n\t70\n',
#  '\n\t\n\tMorgan Wallen\n',
#  '\n\t\n\t57\n',
#  '\n\t\n\t17\n',
#  '\n\t\n\t12\n',
#  '\n\t\n\t57\n',
#  '\n\t\n\t17\n',
#  '\n\t\n\t12\n',
#  '\n\t\n\t71\n',
#  '\n\t\n\tMorgan Wallen\n',
#  '\n\t\n\t55\n',
#  '\n\t\n\t22\n',
#  '\n\t\n\t4\n',
#  '\n\t\n\t55\n',
#  '\n\t\n\t22\n',
#  '\n\t\n\t4\n',
#  '\n\t\n\t72\n',
#  '\n\t\n\tKendrick Lamar Featuring AzChike\n',
#  '\n\t\n\t67\n',
#  '\n\t\n\t13\n',
#  '\n\t\n\t29\n',
#  '\n\t\n\t67\n',
#  '\n\t\n\t13\n',
#  '\n\t\n\t29\n',
#  '\n\t\n\t73\n',
#  '\n\t\n\tAddison Rae\n',
#  '\n\t\n\t94\n',
#  '\n\t\n\t73\n',
#  '\n\t\n\t2\n',
#  '\n\t\n\t94\n',
#  '\n\t\n\t73\n',
#  '\n\t\n\t2\n',
#  '\n\t\n\t74\n',
#  '\n\t\n\tNEW\n',
#  '\n\t\n\tNEW\n',
#  '\n\t\n\tEd Sheeran\n',
#  '\n\t\n\t-\n',
#  '\n\t\n\t74\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t-\n',
#  '\n\t\n\t74\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t75\n',
#  '\n\t\n\tBrandon Lake X Jelly Roll\n',
#  '\n\t\n\t72\n',
#  '\n\t\n\t40\n',
#  '\n\t\n\t17\n',
#  '\n\t\n\t72\n',
#  '\n\t\n\t40\n',
#  '\n\t\n\t17\n',
#  '\n\t\n\t76\n',
#  '\n\t\n\tKane Brown\n',
#  '\n\t\n\t73\n',
#  '\n\t\n\t67\n',
#  '\n\t\n\t14\n',
#  '\n\t\n\t73\n',
#  '\n\t\n\t67\n',
#  '\n\t\n\t14\n',
#  '\n\t\n\t77\n',
#  '\n\t\n\tFuerza Regida\n',
#  '\n\t\n\t71\n',
#  '\n\t\n\t71\n',
#  '\n\t\n\t5\n',
#  '\n\t\n\t71\n',
#  '\n\t\n\t71\n',
#  '\n\t\n\t5\n',
#  '\n\t\n\t78\n',
#  '\n\t\n\tHudson Westbrook\n',
#  '\n\t\n\t79\n',
#  '\n\t\n\t72\n',
#  '\n\t\n\t8\n',
#  '\n\t\n\t79\n',
#  '\n\t\n\t72\n',
#  '\n\t\n\t8\n',
#  '\n\t\n\t79\n',
#  '\n\t\n\tMorgan Wallen\n',
#  '\n\t\n\t64\n',
#  '\n\t\n\t32\n',
#  '\n\t\n\t4\n',
#  '\n\t\n\t64\n',
#  '\n\t\n\t32\n',
#  '\n\t\n\t4\n',
#  '\n\t\n\t80\n',
#  '\n\t\n\tPlayboi Carti & The Weeknd\n',
#  '\n\t\n\t83\n',
#  '\n\t\n\t4\n',
#  '\n\t\n\t13\n',
#  '\n\t\n\t83\n',
#  '\n\t\n\t4\n',
#  '\n\t\n\t13\n',
#  '\n\t\n\t81\n',
#  '\n\t\n\tShaboozey & Jelly Roll\n',
#  '\n\t\n\t75\n',
#  '\n\t\n\t64\n',
#  '\n\t\n\t7\n',
#  '\n\t\n\t75\n',
#  '\n\t\n\t64\n',
#  '\n\t\n\t7\n',
#  '\n\t\n\t82\n',
#  '\n\t\n\tTy Myers\n',
#  '\n\t\n\t88\n',
#  '\n\t\n\t79\n',
#  '\n\t\n\t4\n',
#  '\n\t\n\t88\n',
#  '\n\t\n\t79\n',
#  '\n\t\n\t4\n',
#  '\n\t\n\t83\n',
#  '\n\t\n\tFuerza Regida\n',
#  '\n\t\n\t81\n',
#  '\n\t\n\t81\n',
#  '\n\t\n\t2\n',
#  '\n\t\n\t81\n',
#  '\n\t\n\t81\n',
#  '\n\t\n\t2\n',
#  '\n\t\n\t84\n',
#  '\n\t\n\tMorgan Wallen\n',
#  '\n\t\n\t58\n',
#  '\n\t\n\t21\n',
#  '\n\t\n\t4\n',
#  '\n\t\n\t58\n',
#  '\n\t\n\t21\n',
#  '\n\t\n\t4\n',
#  '\n\t\n\t85\n',
#  '\n\t\n\tMorgan Wallen\n',
#  '\n\t\n\t66\n',
#  '\n\t\n\t29\n',
#  '\n\t\n\t4\n',
#  '\n\t\n\t66\n',
#  '\n\t\n\t29\n',
#  '\n\t\n\t4\n',
#  '\n\t\n\t86\n',
#  '\n\t\n\tFuerza Regida & Grupo Frontera\n',
#  '\n\t\n\t76\n',
#  '\n\t\n\t48\n',
#  '\n\t\n\t17\n',
#  '\n\t\n\t76\n',
#  '\n\t\n\t48\n',
#  '\n\t\n\t17\n',
#  '\n\t\n\t87\n',
#  '\n\t\n\tMorgan Wallen\n',
#  '\n\t\n\t68\n',
#  '\n\t\n\t25\n',
#  '\n\t\n\t4\n',
#  '\n\t\n\t68\n',
#  '\n\t\n\t25\n',
#  '\n\t\n\t4\n',
#  '\n\t\n\t88\n',
#  '\n\t\n\tNate Smith\n',
#  '\n\t\n\t90\n',
#  '\n\t\n\t64\n',
#  '\n\t\n\t11\n',
#  '\n\t\n\t90\n',
#  '\n\t\n\t64\n',
#  '\n\t\n\t11\n',
#  '\n\t\n\t89\n',
#  '\n\t\n\tMorgan Wallen\n',
#  '\n\t\n\t69\n',
#  '\n\t\n\t41\n',
#  '\n\t\n\t4\n',
#  '\n\t\n\t69\n',
#  '\n\t\n\t41\n',
#  '\n\t\n\t4\n',
#  '\n\t\n\t90\n',
#  '\n\t\n\tRE-\nENTRY\n',
#  '\n\t\n\tRE-\nENTRY\n',
#  '\n\t\n\tKATSEYE\n',
#  '\n\t\n\t-\n',
#  '\n\t\n\t90\n',
#  '\n\t\n\t2\n',
#  '\n\t\n\t-\n',
#  '\n\t\n\t90\n',
#  '\n\t\n\t2\n',
#  '\n\t\n\t91\n',
#  '\n\t\n\tMorgan Wallen\n',
#  '\n\t\n\t70\n',
#  '\n\t\n\t34\n',
#  '\n\t\n\t4\n',
#  '\n\t\n\t70\n',
#  '\n\t\n\t34\n',
#  '\n\t\n\t4\n',
#  '\n\t\n\t92\n',
#  '\n\t\n\tBad Bunny\n',
#  '\n\t\n\t84\n',
#  '\n\t\n\t24\n',
#  '\n\t\n\t21\n',
#  '\n\t\n\t84\n',
#  '\n\t\n\t24\n',
#  '\n\t\n\t21\n',
#  '\n\t\n\t93\n',
#  '\n\t\n\tNEW\n',
#  '\n\t\n\tNEW\n',
#  '\n\t\n\tLil Wayne & 2 Chainz\n',
#  '\n\t\n\t-\n',
#  '\n\t\n\t93\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t-\n',
#  '\n\t\n\t93\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t94\n',
#  '\n\t\n\tmgk\n',
#  '\n\t\n\t78\n',
#  '\n\t\n\t62\n',
#  '\n\t\n\t3\n',
#  '\n\t\n\t78\n',
#  '\n\t\n\t62\n',
#  '\n\t\n\t3\n',
#  '\n\t\n\t95\n',
#  '\n\t\n\tNEW\n',
#  '\n\t\n\tNEW\n',
#  '\n\t\n\tMariah Carey\n',
#  '\n\t\n\t-\n',
#  '\n\t\n\t95\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t-\n',
#  '\n\t\n\t95\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t96\n',
#  '\n\t\n\tMorgan Wallen\n',
#  '\n\t\n\t74\n',
#  '\n\t\n\t42\n',
#  '\n\t\n\t4\n',
#  '\n\t\n\t74\n',
#  '\n\t\n\t42\n',
#  '\n\t\n\t4\n',
#  '\n\t\n\t97\n',
#  '\n\t\n\tNEW\n',
#  '\n\t\n\tNEW\n',
#  '\n\t\n\tLil Wayne\n',
#  '\n\t\n\t-\n',
#  '\n\t\n\t97\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t-\n',
#  '\n\t\n\t97\n',
#  '\n\t\n\t1\n',
#  '\n\t\n\t98\n',
#  '\n\t\n\tSabrina Carpenter\n',
#  '\n\t\n\t91\n',
#  '\n\t\n\t27\n',
#  '\n\t\n\t16\n',
#  '\n\t\n\t91\n',
#  '\n\t\n\t27\n',
#  '\n\t\n\t16\n',
#  '\n\t\n\t99\n',
#  '\n\t\n\tMyles Smith\n',
#  '\n\t\n\t100\n',
#  '\n\t\n\t99\n',
#  '\n\t\n\t2\n',
#  '\n\t\n\t100\n',
#  '\n\t\n\t99\n',
#  '\n\t\n\t2\n',
#  '\n\t\n\t100\n',
#  '\n\t\n\tFuerza Regida\n',
#  '\n\t\n\t93\n',
#  '\n\t\n\t64\n',
#  '\n\t\n\t12\n',
#  '\n\t\n\t93\n',
#  '\n\t\n\t64\n',
#  '\n\t\n\t12\n']

# %%
cleaned_artists = [artist.strip() for artist in artists]

# %%
cleaned_artists
# Out:
# ['1',
#  'NEW',
#  'NEW',
#  'Sabrina Carpenter',
#  '-',
#  '1',
#  '1',
#  '-',
#  '1',
#  '1',
#  '2',
#  'Alex Warren',
#  '1',
#  '1',
#  '18',
#  '1',
#  '1',
#  '18',
#  '3',
#  'Morgan Wallen Featuring Tate McRae',
#  '2',
#  '1',
#  '4',
#  '2',
#  '1',
#  '4',
#  '4',
#  'Morgan Wallen',
#  '3',
#  '2',
#  '12',
#  '3',
#  '2',
#  '12',
#  '5',
#  'Kendrick Lamar & SZA',
#  '4',
#  '1',
#  '29',
#  '4',
#  '1',
#  '29',
#  '6',
#  'Morgan Wallen',
#  '5',
#  '2',
#  '19',
#  '5',
#  '2',
#  '19',
#  '7',
#  'Shaboozey',
#  '6',
#  '1',
#  '61',
#  '6',
#  '1',
#  '61',
#  '8',
#  'Lady Gaga & Bruno Mars',
#  '7',
#  '1',
#  '43',
#  '7',
#  '1',
#  '43',
#  '9',
#  'Teddy Swims',
#  '8',
#  '1',
#  '95',
#  '8',
#  '1',
#  '95',
#  '10',
#  'Benson Boone',
#  '9',
#  '2',
#  '72',
#  '9',
#  '2',
#  '72',
#  '11',
#  'Chappell Roan',
#  '12',
#  '4',
#  '52',
#  '12',
#  '4',
#  '52',
#  '12',
#  'Drake',
#  '10',
#  '2',
#  '17',
#  '10',
#  '2',
#  '17',
#  '13',
#  'Doechii',
#  '11',
#  '9',
#  '14',
#  '11',
#  '9',
#  '14',
#  '14',
#  'Leon Thomas',
#  '14',
#  '13',
#  '19',
#  '14',
#  '13',
#  '19',
#  '15',
#  'Post Malone Featuring Morgan Wallen',
#  '15',
#  '1',
#  '57',
#  '15',
#  '1',
#  '57',
#  '16',
#  'Billie Eilish',
#  '13',
#  '2',
#  '56',
#  '13',
#  '2',
#  '56',
#  '17',
#  'Sabrina Carpenter',
#  '20',
#  '3',
#  '61',
#  '20',
#  '3',
#  '61',
#  '18',
#  'Jessie Murph',
#  '16',
#  '15',
#  '9',
#  '16',
#  '15',
#  '9',
#  '19',
#  'BigXthaPlug Featuring Bailey Zimmerman',
#  '18',
#  '4',
#  '10',
#  '18',
#  '4',
#  '10',
#  '20',
#  'Riley Green',
#  '23',
#  '20',
#  '22',
#  '23',
#  '20',
#  '22',
#  '21',
#  'Morgan Wallen',
#  '17',
#  '7',
#  '4',
#  '17',
#  '7',
#  '4',
#  '22',
#  'Morgan Wallen',
#  '19',
#  '1',
#  '34',
#  '19',
#  '1',
#  '34',
#  '23',
#  'Ravyn Lenae',
#  '36',
#  '23',
#  '11',
#  '36',
#  '23',
#  '11',
#  '24',
#  'ROSE & Bruno Mars',
#  '24',
#  '3',
#  '34',
#  '24',
#  '3',
#  '34',
#  '25',
#  'Morgan Wallen Featuring Post Malone',
#  '21',
#  '8',
#  '8',
#  '21',
#  '8',
#  '8',
#  '26',
#  'SZA With Kendrick Lamar',
#  '28',
#  '10',
#  '25',
#  '28',
#  '10',
#  '25',
#  '27',
#  'Tate McRae',
#  '22',
#  '16',
#  '20',
#  '22',
#  '16',
#  '20',
#  '28',
#  'Ella Langley',
#  '30',
#  '28',
#  '19',
#  '30',
#  '28',
#  '19',
#  '29',
#  'Morgan Wallen',
#  '27',
#  '20',
#  '4',
#  '27',
#  '20',
#  '4',
#  '30',
#  'Benson Boone',
#  '35',
#  '30',
#  '7',
#  '35',
#  '30',
#  '7',
#  '31',
#  'Benson Boone',
#  '32',
#  '30',
#  '15',
#  '32',
#  '30',
#  '15',
#  '32',
#  'sombr',
#  '38',
#  '32',
#  '11',
#  '38',
#  '32',
#  '11',
#  '33',
#  'The Weeknd & Playboi Carti',
#  '31',
#  '3',
#  '37',
#  '31',
#  '3',
#  '37',
#  '34',
#  'sombr',
#  '25',
#  '25',
#  '10',
#  '25',
#  '25',
#  '10',
#  '35',
#  'Gracie Abrams',
#  '37',
#  '6',
#  '34',
#  '37',
#  '6',
#  '34',
#  '36',
#  'NEW',
#  'NEW',
#  'Lil Wayne & BigXthaPlug Featuring Jay Jones',
#  '-',
#  '36',
#  '1',
#  '-',
#  '36',
#  '1',
#  '37',
#  'Lola Young',
#  '29',
#  '14',
#  '28',
#  '29',
#  '14',
#  '28',
#  '38',
#  'Morgan Wallen',
#  '26',
#  '8',
#  '5',
#  '26',
#  '8',
#  '5',
#  '39',
#  'Shaboozey',
#  '44',
#  '34',
#  '29',
#  '44',
#  '34',
#  '29',
#  '40',
#  'Mariah The Scientist',
#  '41',
#  '25',
#  '6',
#  '41',
#  '25',
#  '6',
#  '41',
#  'Lady Gaga',
#  '42',
#  '13',
#  '19',
#  '42',
#  '13',
#  '19',
#  '42',
#  'NEW',
#  'NEW',
#  'GloRilla',
#  '-',
#  '42',
#  '1',
#  '-',
#  '42',
#  '1',
#  '43',
#  'Kendrick Lamar Featuring Lefty Gunplay',
#  '40',
#  '2',
#  '29',
#  '40',
#  '2',
#  '29',
#  '44',
#  'Billie Eilish',
#  '48',
#  '17',
#  '52',
#  '48',
#  '17',
#  '52',
#  '45',
#  'Megan Moroney',
#  '34',
#  '34',
#  '40',
#  '34',
#  '34',
#  '40',
#  '46',
#  'The Weeknd',
#  '46',
#  '12',
#  '19',
#  '46',
#  '12',
#  '19',
#  '47',
#  'The Marias',
#  '39',
#  '22',
#  '37',
#  '39',
#  '22',
#  '37',
#  '48',
#  'Bailey Zimmerman & Luke Combs',
#  '52',
#  '36',
#  '6',
#  '52',
#  '36',
#  '6',
#  '49',
#  'Russell Dickerson',
#  '54',
#  '49',
#  '8',
#  '54',
#  '49',
#  '8',
#  '50',
#  'Kendrick Lamar',
#  '47',
#  '1',
#  '29',
#  '47',
#  '1',
#  '29',
#  '51',
#  'Tate McRae',
#  '33',
#  '33',
#  '2',
#  '33',
#  '33',
#  '2',
#  '52',
#  'Morgan Wallen',
#  '43',
#  '31',
#  '4',
#  '43',
#  '31',
#  '4',
#  '53',
#  'Alex Warren With Jelly Roll',
#  '45',
#  '32',
#  '3',
#  '45',
#  '32',
#  '3',
#  '54',
#  'NEW',
#  'NEW',
#  'Lil Wayne, Jelly Roll & Big Sean',
#  '-',
#  '54',
#  '1',
#  '-',
#  '54',
#  '1',
#  '55',
#  'MOLIY, Silent Addy, Skillibeng & Shenseea',
#  '56',
#  '55',
#  '4',
#  '56',
#  '55',
#  '4',
#  '56',
#  'NEW',
#  'NEW',
#  'Jessie Murph',
#  '-',
#  '56',
#  '1',
#  '-',
#  '56',
#  '1',
#  '57',
#  'PARTYNEXTDOOR & Drake',
#  '59',
#  '30',
#  '17',
#  '59',
#  '30',
#  '17',
#  '58',
#  'Thomas Rhett',
#  '60',
#  '58',
#  '7',
#  '60',
#  '58',
#  '7',
#  '59',
#  'Ed Sheeran',
#  '61',
#  '28',
#  '10',
#  '61',
#  '28',
#  '10',
#  '60',
#  'Morgan Wallen',
#  '49',
#  '49',
#  '4',
#  '49',
#  '49',
#  '4',
#  '61',
#  'NEW',
#  'NEW',
#  'Lil Wayne',
#  '-',
#  '61',
#  '1',
#  '-',
#  '61',
#  '1',
#  '62',
#  'NEW',
#  'NEW',
#  'Lil Wayne',
#  '-',
#  '62',
#  '1',
#  '-',
#  '62',
#  '1',
#  '63',
#  'Lil Tecca',
#  '53',
#  '28',
#  '13',
#  '53',
#  '28',
#  '13',
#  '64',
#  'Charli xcx',
#  '62',
#  '55',
#  '8',
#  '62',
#  '55',
#  '8',
#  '65',
#  'NEW',
#  'NEW',
#  'Lil Wayne',
#  '-',
#  '65',
#  '1',
#  '-',
#  '65',
#  '1',
#  '66',
#  'PLUTO & YKNIECE',
#  '51',
#  '51',
#  '8',
#  '51',
#  '51',
#  '8',
#  '67',
#  'Sam Barber Featuring Avery Anna',
#  '65',
#  '40',
#  '27',
#  '65',
#  '40',
#  '27',
#  '68',
#  'Forrest Frank',
#  '63',
#  '61',
#  '8',
#  '63',
#  '61',
#  '8',
#  '69',
#  'Lil Tecca',
#  '50',
#  '50',
#  '2',
#  '50',
#  '50',
#  '2',
#  '70',
#  'Morgan Wallen',
#  '57',
#  '17',
#  '12',
#  '57',
#  '17',
#  '12',
#  '71',
#  'Morgan Wallen',
#  '55',
#  '22',
#  '4',
#  '55',
#  '22',
#  '4',
#  '72',
#  'Kendrick Lamar Featuring AzChike',
#  '67',
#  '13',
#  '29',
#  '67',
#  '13',
#  '29',
#  '73',
#  'Addison Rae',
#  '94',
#  '73',
#  '2',
#  '94',
#  '73',
#  '2',
#  '74',
#  'NEW',
#  'NEW',
#  'Ed Sheeran',
#  '-',
#  '74',
#  '1',
#  '-',
#  '74',
#  '1',
#  '75',
#  'Brandon Lake X Jelly Roll',
#  '72',
#  '40',
#  '17',
#  '72',
#  '40',
#  '17',
#  '76',
#  'Kane Brown',
#  '73',
#  '67',
#  '14',
#  '73',
#  '67',
#  '14',
#  '77',
#  'Fuerza Regida',
#  '71',
#  '71',
#  '5',
#  '71',
#  '71',
#  '5',
#  '78',
#  'Hudson Westbrook',
#  '79',
#  '72',
#  '8',
#  '79',
#  '72',
#  '8',
#  '79',
#  'Morgan Wallen',
#  '64',
#  '32',
#  '4',
#  '64',
#  '32',
#  '4',
#  '80',
#  'Playboi Carti & The Weeknd',
#  '83',
#  '4',
#  '13',
#  '83',
#  '4',
#  '13',
#  '81',
#  'Shaboozey & Jelly Roll',
#  '75',
#  '64',
#  '7',
#  '75',
#  '64',
#  '7',
#  '82',
#  'Ty Myers',
#  '88',
#  '79',
#  '4',
#  '88',
#  '79',
#  '4',
#  '83',
#  'Fuerza Regida',
#  '81',
#  '81',
#  '2',
#  '81',
#  '81',
#  '2',
#  '84',
#  'Morgan Wallen',
#  '58',
#  '21',
#  '4',
#  '58',
#  '21',
#  '4',
#  '85',
#  'Morgan Wallen',
#  '66',
#  '29',
#  '4',
#  '66',
#  '29',
#  '4',
#  '86',
#  'Fuerza Regida & Grupo Frontera',
#  '76',
#  '48',
#  '17',
#  '76',
#  '48',
#  '17',
#  '87',
#  'Morgan Wallen',
#  '68',
#  '25',
#  '4',
#  '68',
#  '25',
#  '4',
#  '88',
#  'Nate Smith',
#  '90',
#  '64',
#  '11',
#  '90',
#  '64',
#  '11',
#  '89',
#  'Morgan Wallen',
#  '69',
#  '41',
#  '4',
#  '69',
#  '41',
#  '4',
#  '90',
#  'RE-\nENTRY',
#  'RE-\nENTRY',
#  'KATSEYE',
#  '-',
#  '90',
#  '2',
#  '-',
#  '90',
#  '2',
#  '91',
#  'Morgan Wallen',
#  '70',
#  '34',
#  '4',
#  '70',
#  '34',
#  '4',
#  '92',
#  'Bad Bunny',
#  '84',
#  '24',
#  '21',
#  '84',
#  '24',
#  '21',
#  '93',
#  'NEW',
#  'NEW',
#  'Lil Wayne & 2 Chainz',
#  '-',
#  '93',
#  '1',
#  '-',
#  '93',
#  '1',
#  '94',
#  'mgk',
#  '78',
#  '62',
#  '3',
#  '78',
#  '62',
#  '3',
#  '95',
#  'NEW',
#  'NEW',
#  'Mariah Carey',
#  '-',
#  '95',
#  '1',
#  '-',
#  '95',
#  '1',
#  '96',
#  'Morgan Wallen',
#  '74',
#  '42',
#  '4',
#  '74',
#  '42',
#  '4',
#  '97',
#  'NEW',
#  'NEW',
#  'Lil Wayne',
#  '-',
#  '97',
#  '1',
#  '-',
#  '97',
#  '1',
#  '98',
#  'Sabrina Carpenter',
#  '91',
#  '27',
#  '16',
#  '91',
#  '27',
#  '16',
#  '99',
#  'Myles Smith',
#  '100',
#  '99',
#  '2',
#  '100',
#  '99',
#  '2',
#  '100',
#  'Fuerza Regida',
#  '93',
#  '64',
#  '12',
#  '93',
#  '64',
#  '12']

# %%
# Filtering only artist names
filtered_artists = [artist for artist in cleaned_artists if not artist.isdigit() and artist not in ["NEW", "-", "RE-\nENTRY"]]

# %%
filtered_artists
# Out:
# ['Sabrina Carpenter',
#  'Alex Warren',
#  'Morgan Wallen Featuring Tate McRae',
#  'Morgan Wallen',
#  'Kendrick Lamar & SZA',
#  'Morgan Wallen',
#  'Shaboozey',
#  'Lady Gaga & Bruno Mars',
#  'Teddy Swims',
#  'Benson Boone',
#  'Chappell Roan',
#  'Drake',
#  'Doechii',
#  'Leon Thomas',
#  'Post Malone Featuring Morgan Wallen',
#  'Billie Eilish',
#  'Sabrina Carpenter',
#  'Jessie Murph',
#  'BigXthaPlug Featuring Bailey Zimmerman',
#  'Riley Green',
#  'Morgan Wallen',
#  'Morgan Wallen',
#  'Ravyn Lenae',
#  'ROSE & Bruno Mars',
#  'Morgan Wallen Featuring Post Malone',
#  'SZA With Kendrick Lamar',
#  'Tate McRae',
#  'Ella Langley',
#  'Morgan Wallen',
#  'Benson Boone',
#  'Benson Boone',
#  'sombr',
#  'The Weeknd & Playboi Carti',
#  'sombr',
#  'Gracie Abrams',
#  'Lil Wayne & BigXthaPlug Featuring Jay Jones',
#  'Lola Young',
#  'Morgan Wallen',
#  'Shaboozey',
#  'Mariah The Scientist',
#  'Lady Gaga',
#  'GloRilla',
#  'Kendrick Lamar Featuring Lefty Gunplay',
#  'Billie Eilish',
#  'Megan Moroney',
#  'The Weeknd',
#  'The Marias',
#  'Bailey Zimmerman & Luke Combs',
#  'Russell Dickerson',
#  'Kendrick Lamar',
#  'Tate McRae',
#  'Morgan Wallen',
#  'Alex Warren With Jelly Roll',
#  'Lil Wayne, Jelly Roll & Big Sean',
#  'MOLIY, Silent Addy, Skillibeng & Shenseea',
#  'Jessie Murph',
#  'PARTYNEXTDOOR & Drake',
#  'Thomas Rhett',
#  'Ed Sheeran',
#  'Morgan Wallen',
#  'Lil Wayne',
#  'Lil Wayne',
#  'Lil Tecca',
#  'Charli xcx',
#  'Lil Wayne',
#  'PLUTO & YKNIECE',
#  'Sam Barber Featuring Avery Anna',
#  'Forrest Frank',
#  'Lil Tecca',
#  'Morgan Wallen',
#  'Morgan Wallen',
#  'Kendrick Lamar Featuring AzChike',
#  'Addison Rae',
#  'Ed Sheeran',
#  'Brandon Lake X Jelly Roll',
#  'Kane Brown',
#  'Fuerza Regida',
#  'Hudson Westbrook',
#  'Morgan Wallen',
#  'Playboi Carti & The Weeknd',
#  'Shaboozey & Jelly Roll',
#  'Ty Myers',
#  'Fuerza Regida',
#  'Morgan Wallen',
#  'Morgan Wallen',
#  'Fuerza Regida & Grupo Frontera',
#  'Morgan Wallen',
#  'Nate Smith',
#  'Morgan Wallen',
#  'KATSEYE',
#  'Morgan Wallen',
#  'Bad Bunny',
#  'Lil Wayne & 2 Chainz',
#  'mgk',
#  'Mariah Carey',
#  'Morgan Wallen',
#  'Lil Wayne',
#  'Sabrina Carpenter',
#  'Myles Smith',
#  'Fuerza Regida']

# %%
len(filtered_artists)
# Out:
# 100

# %%
billboard_dict = {"song":unique_songs, "artist":filtered_artists}

billboard_df = pd.DataFrame(billboard_dict)
billboard_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 3
#       1 billboard_dict = {"song":unique_songs, "artist":filtered_artists}
# ----> 3 billboard_df = pd.DataFrame(billboard_dict)
#       4 billboard_df.head()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:677, in _extract_index(data)
#     675 lengths = list(set(raw_lengths))
#     676 if len(lengths) > 1:
# --> 677     raise ValueError("All arrays must be of the same length")
#     679 if have_dicts:
#     680     raise ValueError(
#     681         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     682     )
#
# ValueError: All arrays must be of the same length

# %%
billboard_df

# %%
billboard_df.to_csv("billboard_data.csv", index=False)
